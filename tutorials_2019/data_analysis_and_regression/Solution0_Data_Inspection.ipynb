# %% [markdown]
# ## Exercise 0 : Data inspection

# %%
import numpy as np

# %%
# Load data
filename = "ANN_7ksliced.pk"
data = np.load(filename)

# %%
type(data)
# Out:
# list

# %%
# just print data, huge output
data
# Out:
# [{'dvarNames': ['P0', 'P1', 'G0', 'G1', 'K1', 'K2'],
#   'sampleSize': 1,
#   'objNames': ['rms_x',
#    'rms_y',
#    'rms_s',
#    'emit_x',
#    'emit_y',
#    'emit_s',
#    'dE',
#    'energy',
#    's',
#    'numParticles']},
#  {'dvarValues': [['-5.68642459380506',
#     '-7.9440663186058',
#     '65.2305550162159',
#     '20.6450631644844',
#     '531.648132679761',
#     '212.70486026435'],
#    ['-8.83361314072777',
#     '-5.55141750878421',
#     '64.8241989131995',
#     '22.271654866922',
#     '455.320146267926',
#     '251.036328438066'],
#    ['-9.42612498238869',
#     '-3.09323193685354',
#     '66.0634733799934',
#     '19.2024487060933',
#     '532.481816635128',
#     '255.493562452738'],
#    ['-0.621975820569265',
#     '-1.01108479132239',
#     '65.1741761757976',
#     '18.448262335958',
#     '401.888766543931',
#     '217.164584582445'],
#    ['-6.92743972920622',
#     '-3.12131444769813',
#     '64.4751192079513',
#     '17.8963827512127',
# ...

# %%
len(data)
# Out:
# 2

# %%
data[0]
# Out:
# {'dvarNames': ['P0', 'P1', 'G0', 'G1', 'K1', 'K2'],
#  'sampleSize': 1,
#  'objNames': ['rms_x',
#   'rms_y',
#   'rms_s',
#   'emit_x',
#   'emit_y',
#   'emit_s',
#   'dE',
#   'energy',
#   's',
#   'numParticles']}

# %%
type(data[0])
# Out:
# dict

# %%
data[0].keys()
# Out:
# dict_keys(['dvarNames', 'sampleSize', 'objNames'])

# %%
type(data[1])
# Out:
# dict

# %%
data[1].keys()
# Out:
# dict_keys(['dvarValues', 'objValues'])

# %%
# redefine for simplicity
values = data[1]

# %%
np.shape(values['dvarValues'])
# Out:
# (7000, 6)

# %%
values['dvarValues'][0]
# Out:
# ['-5.68642459380506',
#  '-7.9440663186058',
#  '65.2305550162159',
#  '20.6450631644844',
#  '531.648132679761',
#  '212.70486026435']
